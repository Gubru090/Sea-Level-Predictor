# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Load the data
df = pd.read_csv('epa-sea-level.csv')

# %%
def draw_plot():
    # Create a scatter plot
    plt.scatter(df['Year'], df['CSIRO Adjusted Sea Level'], color='blue')

# %%
    # Perform linear regression on the entire dataset
    slope, intercept, r_value, p_value, std_err = linregress(df['Year'], df['CSIRO Adjusted Sea Level'])
    
    # Predict sea levels up to 2050
    years_extended = pd.Series(range(1880, 2051))
    sea_level_predicted = intercept + slope * years_extended
    
    # Plot the line of best fit
    plt.plot(years_extended, sea_level_predicted, color='red', label='Best fit line (1880-2050)')

# %%
    # Create a new dataset from the year 2000 onwards
    df_recent = df[df['Year'] >= 2000]
    
    # Perform linear regression on the recent data
    slope_recent, intercept_recent, r_value, p_value, std_err = linregress(df_recent['Year'], df_recent['CSIRO Adjusted Sea Level'])
    
    # Predict sea levels from 2000 to 2050
    recent_years_extended = pd.Series(range(2000, 2051))
    recent_sea_level_predicted = intercept_recent + slope_recent * recent_years_extended
    
    # Plot the second line of best fit
    plt.plot(recent_years_extended, recent_sea_level_predicted, color='green', label='Best fit line (2000-2050)')

# %%
    # Add labels and title
    plt.xlabel('Year')
    plt.ylabel('Sea Level (inches)')
    plt.title('Rise in Sea Level')

    # Add legend
    plt.legend()

    # Save the plot
    plt.savefig('sea_level_plot.png')
    
    return plt.gca()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6852\2726161475.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
#   Cell In[6], line 12
#     return plt.gca()
#     ^
# SyntaxError: 'return' outside function
